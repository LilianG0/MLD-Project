# %%
import xarray as xr
import numpy as np
import datetime
import pandas as pd
#import gsw
from scipy import interpolate

import matplotlib as mpl
import matplotlib.pyplot as plt


import cartopy
import cartopy.feature as cfeat
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import xarray as xr
import numpy as np

from matplotlib import colors
from matplotlib import ticker
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.animation as animation
from IPython.display import HTML

# %%
# Coordinates for large regions. Position in
# (lon, lat): (rigth,  letf), (south, north),
# and title for an eventual ploting title.
reg_ext = {
    'lab': {
        'lon' : (-60, -30),
        'lat' : (50, 65),
        'name' : 'Labrador and Irminger Seas'
    },
    'gul': {
        'lon' : (-75, -45),
        'lat' : (30, 45),
        'name' : 'Gulf Stream'
    },
    'noe': {
        'lon' : (-30, -5),
        'lat' : (45, 60),
        'name' : 'North East Sea'
    },
    'nor':{
        'lon' : (-15, 10.),
        'lat' : (65, 80),
        'name' : 'North Atlantic Ocean'
    },
    'noa':{
        'lon' : (-90, 15.),
        'lat' : (10, 85),
        'name' : 'North Atlantic Ocean'
    }
}

# %%
## Function to crop the dataset
def Crops(coord, d_set):
    """
        Crops is a function that takes a data set and crops it into smaller
        region, using as parameters the values given by the dictionary 
        reg_ext.
        
        Parameters:
        ------------
            
        coord : string
            Key value that identifies the region to obtain
        
        d_set : DataArray
            Dataset to be cropped
        
        Output:
        -------
        new_ds : DataArray
            New data array corresponding to the region stated by 'coord'
    """
    
    lon1, lon2 = reg_ext[coord]['lon']
    lat1, lat2 = reg_ext[coord]['lat']
    name_fig = reg_ext[coord]['name']
    
    new_ds = d_set.sel(longitude=slice(lon1, lon2), latitude=slice(lat1, lat2))
    return(new_ds)


def Grid(data_set):
    x = data_set.longitude
    y = data_set.latitude
    
    x, y = np.meshgrid(x, y)
    return(x, y)


def No_nan(a):
    """
        No_nan is a function that helps to filter an array from nan values.
        
        Parameters:
        ------------
        a : Numpy Array
            Is the array we want to filter
        
        Output:
        -------
        a2 : Numpy Arrray
            Array with no nan values in it
    """
    nan_array = np.isnan(a)
    not_nan_array = ~ nan_array
    a2 = a[not_nan_array]
    
    return(a2)


def Map(ax, region, xtick, ytick):
    """
        Map is a function that helps to plot the map on a certain projection
        of a region. It always uses 50m definition of coastlines.

        Parameters:
        ------------
        ax : axes
            Current axes object in which is drawn the map.

        region : list
            Set of limit coordinates of the region to plot.
            It has the shape [lon1, lon2, lat1, lat2]

        xtick : np.array
            array containing the number and spacement of ticks 
            in x-axis.

        ytick : np.array
            Array containing the number and spacement of ticks 
            in y-axis.
    """
    ax.set_global()
    ax.coastlines('50m')
    ax.set_xticks(xtick, crs=ccrs.PlateCarree())
    ax.set_yticks(ytick, crs=ccrs.PlateCarree())
    lon_formatter = LongitudeFormatter(zero_direction_label=True)
    lat_formatter = LatitudeFormatter()

    ax.xaxis.set_major_formatter(lon_formatter)
    ax.yaxis.set_major_formatter(lat_formatter)
    ax.add_feature(cartopy.feature.BORDERS, linestyle=':')
    ax.set_extent(region, crs=ccrs.PlateCarree())     #lat, lon
    ax.gridlines(crs=ccrs.PlateCarree(), linewidth=1, 
                 color='gray', alpha=0.5, linestyle='-.')



## Need to make this a little bit more general, also in the extend. by now extends just to max
def Plot_2D(data_set, reg, *cm_levs, t=None, cmap=None, ext=None, cont_line=False, nlines=None):
    """
        Plot_2D is a function that plots a 2D variable using a
        colormap over a spatial region. It makes use of the external 
        functions 'Grid' and 'Map'. It also makes use of the dictionary 
        'reg_ext', to get the spatial delimitations. This works only
        for DataArray type and to plot MLD. The pre-defined cmap is 
        'magma_r'.
        
        Parameters:
        ------------
        data_set : DataArray
            Current axes object in which is drawn the map. It can
            be a complete DataArray, or just the values for one of
            the variables.
            
        reg : string
            Abreviation name that identifies the region in 
            which the plot is being done. It must be defined
            inside the dictionary 'reg_ext'.
            
        cm_levs : tuple, integers
            It contains the parameters for the color bar. The 
            order is: minimum, maximum, #of levels
        
        t : integer
            Timestep to plot.
        
        cmap : String
            Name of the color map to use. Default is 'magma_r'
        
        ext : string
            Extention of the color bar. Default is 'max'
            
        cont_line : Boolean
            If True we allow to plot a second contour plot of SSH. 
            On top of the MLD heat map.
            If False, this function plots a heat map of the variable 
            set by parameter 'data_set'.
            
        nlines : integers
            Is the number of lines to plot the contour plot. It is 
            optional, and is necessary when cont_line=True.
        
        Output:
        ------------
        ax : axes
    """
    
    # Shaping the plot
    x_n, y_n = Grid(data_set)
    projection = ccrs.PlateCarree(360)
    
    # Getting the delimitations and ticks
    lon1, lon2 = reg_ext[reg]['lon']
    lat1, lat2 = reg_ext[reg]['lat']
    xtick = np.linspace(lon1, lon2, num=9)
    ytick = np.linspace(lat1, lat2, num=4)
    region = [lon1, lon2, lat1, lat2]    #Lon, Lat
    
    # If we want to plot MLD and SSH, or other thing, without SSH countours
    if cont_line:
        if not t:
            variable1 = data_set.mlotst
            variable2 = data_set.zo[0]
        else:
            variable1 = data_set.mlotst[t]
            variable2 = data_set.zo[t,0]
    else:
        if not t:
            variable1 = data_set
        else:
            variable1 = data_set[t]
        
    if not cmap:
        cmap = 'plasma_r'
        
    
    if ext:
        ext = ext
    else:
        ext = 'max'

    # Start of the plot
    fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), figsize=(10,5))    
    
    Map(ax, region, xtick, ytick)
    
    # Here plot the variable using a heat map, defining also color bar
    contr1 = ax.contourf(x_n, y_n, variable1, 
                         levels=np.linspace(cm_levs[0], cm_levs[1], cm_levs[2]),
                         cmap=cmap, extend=ext)
    cbar = fig.colorbar(contr1, ax=ax, shrink=0.855, orientation='vertical',
                        label='MLD [m]', extend=ext)  
    # Here adding an extra layer of SSH at surface using countour lines
    if cont_line:
        contr2 = ax.contour(x_n, y_n, variable2, nlines, linewidths=0.5, colors='k')
    
    # Saving the figure
    ##if save:
    ##    fig.savefig(os.path.abspath(os.path.sep.join([".","dummy_images","Noe_%0.4d.png" % it])))

    return(ax)
    
    
def Masking(data_set, cond):
    """
        Maskin is a function that makes a mask of an array depending on the 
        entering condition. The condition is evaluated over finite numbers.
        At the final, the mask is appended in the original DataArray as a 
        new coordinate.
        
        Parameters:
        ------------
        data_set : DataArray
            Is the array we want to make the mask of.
            
        cond : array
            Codition to meet. 


        Output:
        -------
        data_set : Numpy Arrray
            Array with new coordinates 'mask'
    """
    
    mask = 1 * np.ones((data_set.dims['latitude'], data_set.dims['longitude'])) * np.isfinite(cond)  
    data_set.coords['mask'] = (('latitude', 'longitude'), mask)
    return(data_set)


def Limits(data_set):
    
    mn = data_set.min(skipna=True).values
    mx = data_set.max(skipna=True).values
    return(mn, mx)

# %%
###############################################################################
###########         MAIN PROGRAM
###############################################################################

dir_1 = '../../../New_ARMOR/'
dir_15 = '/net/data0-gw/data0/project/drakkar/USERS/lgarcia/data_ARMOR/'
dir_2= '/net/alpha/exports/sciences/data/LPO_ISAS/ANA_ISAS15/fld2D/'

dir_o = '/home/lgarcia/Documents/Scripts/Images_01/'


fl_n1 = 'NARMOR_*.nc'
fl_n15 = 'ARMOR_*.nc'

c_armor1 = xr.open_mfdataset(dir_1 + fl_n1, concat_dim='time')
c_armor15 = xr.open_mfdataset(dir_15 + fl_n15)


fl_n2 = 'ISAS15_DM_2006_2015_MLDS.nc'
fl_n3 = 'ISAS15_DM_2002_2015_MLDS_0.03.nc'
fl_n4 = 'ISAS15_DM_2002_2015_MLDS_0.015.nc'
fl_n5 = 'ISAS15_DM_2002_2015_MLDS_0.046.nc'

c_isas1 = xr.open_dataset(dir_2 + fl_n2, autoclose=True)
c_isas2 = xr.open_dataset(dir_2 + fl_n3, autoclose=True)
c_isas3 = xr.open_dataset(dir_2 + fl_n4, autoclose=True)
c_isas4 = xr.open_dataset(dir_2 + fl_n5, autoclose=True)
# Out:
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/times.py:132: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   enable_cftimeindex)
# /usr/local/lib/python3.5/dist-packages/xarray/coding/variables.py:69: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using dummy cftime.datetime objects instead, reason: dates out of range
#   return self.func(self.array)

# %%
d1 = datetime.datetime(2005,1,1)
d2 = datetime.datetime(2018,12,20)

weeks = pd.date_range(start=d1, end=d2, freq='7D')
c_armor1.coords['time'] = (('time'), weeks)

# %%
reg = 'nor'
## File format :: t, lat, lon
nor1 = Crops(reg, c_armor1)
nor15 = Crops(reg, c_armor15)

nor15 = Masking(nor15, nor15.to[0,25])

norI1 = Crops(reg, c_isas1)
norI2 = Crops(reg, c_isas2)
norI3 = Crops(reg, c_isas3)
norI4 = Crops(reg, c_isas4)

# %%
del c_armor1, c_armor15, c_isas1, c_isas2, c_isas3, c_isas4

# %%
mean1 = nor1.mean(dim='time', skipna=True)
stdv1 = nor1.std(dim='time', skipna=True)

# All dataset
min_mldm, max_mldm = Limits(mean1.mlotst.where(nor15.mask==1))    # Min, max values mean MLD
min_mlds, max_mlds = Limits(stdv1.mlotst.where(nor15.mask==1))    # Min, max values std MLD

print('mean \t\t std')
print(min_mldm, max_mldm, min_mlds, max_mlds)
# Out:
# /usr/local/lib/python3.5/dist-packages/dask/array/numpy_compat.py:28: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /usr/local/lib/python3.5/dist-packages/dask/array/reductions.py:384: RuntimeWarning: invalid value encountered in true_divide
#   u = total / n
# /usr/local/lib/python3.5/dist-packages/dask/array/numpy_compat.py:28: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# mean 		 std
# 13.205761316872428 174.7900709219858 3.4904564993241527 393.7494449943115

# %% [markdown]
# ## Mean + std :: MLD

# %%
# %matplotlib notebook

plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)

x_n, y_n = Grid(nor1)

projection = ccrs.PlateCarree(360)
region = [lon1, lon2, lat1, lat2]    #Lon, Lat

# Variables to plot
mapping_var = mean1.mlotst    # In the colormap
contour_var = stdv1.mlotst    # Variable to plot in lines

cb_label = 'mean MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(10., 700., 25)
n_lines = 11


## Title for the figure
fig_title = 'Nordic Sea Mixed Layer Depth [m] \n ARMOR 3D'  

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                        figsize=(10,5)) 

Map(ax, region, xtik, ytik)

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='max')

cbar = fig.colorbar(contr1, ax=ax, shrink=0.95, orientation='vertical',
                    label=cb_label) 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k')


#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=8, inline=10)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-mld-ms-A.png', bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# /usr/local/lib/python3.5/dist-packages/dask/array/numpy_compat.py:28: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py:6449: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py:6449: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /usr/local/lib/python3.5/dist-packages/dask/array/reductions.py:384: RuntimeWarning: invalid value encountered in true_divide
#   u = total / n

# %%
meanI1 = norI1.mean(dim='time', skipna=True)
stdvI1 = norI1.std(dim='time', skipna=True)

meanI1.MLDP[0].max(skipna=True).values
# Out:
# /usr/local/lib/python3.5/dist-packages/xarray/core/nanops.py:162: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /usr/local/lib/python3.5/dist-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# array(515.7917, dtype=float32)

# %%
# %matplotlib notebook

plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)

x_n, y_n = Grid(norI1)

projection = ccrs.PlateCarree(360)
region = [lon1, lon2, lat1, lat2]    #Lon, Lat

# Variables to plot
mapping_var = meanI1.MLDP[0]    # In the colormap
contour_var = stdvI1.MLDP[0]    # Variable to plot in lines

cb_label = 'mean MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(10., 700., 25)
n_lines = 11


## Title for the figure
fig_title = 'Nordic Sea Mixed Layer Depth [m] \n ISAS-Original'  

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                        figsize=(10,5)) 

Map(ax, region, xtik, ytik)

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='max')

cbar = fig.colorbar(contr1, ax=ax, shrink=0.95, orientation='vertical',
                    label=cb_label) 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k')


#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=8, inline=10)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-mld-ms-I1.png', bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py:6449: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py:6449: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)

# %%
meanI2 = norI2.mean(dim='time', skipna=True)
stdvI2 = norI2.std(dim='time', skipna=True)

meanI2.MLDP[0].max(skipna=True).values
# Out:
# /usr/local/lib/python3.5/dist-packages/xarray/core/nanops.py:162: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /usr/local/lib/python3.5/dist-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# array(518.9583, dtype=float32)

# %%
# %matplotlib notebook

plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)

x_n, y_n = Grid(norI1)

projection = ccrs.PlateCarree(360)
region = [lon1, lon2, lat1, lat2]    #Lon, Lat

# Variables to plot
mapping_var = meanI2.MLDP[0]    # In the colormap
contour_var = stdvI2.MLDP[0]    # Variable to plot in lines

cb_label = 'mean MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(10., 700., 25)
n_lines = 11


## Title for the figure
fig_title = 'Nordic Sea Mixed Layer Depth [m] \n ISAS-0.030'  

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                        figsize=(10,5)) 

Map(ax, region, xtik, ytik)

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='max')

cbar = fig.colorbar(contr1, ax=ax, shrink=0.95, orientation='vertical',
                    label=cb_label) 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k')


#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=8, inline=10)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-mld-ms-I2.png', bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py:6449: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py:6449: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)

# %%
meanI3 = norI3.mean(dim='time', skipna=True)
stdvI3 = norI3.std(dim='time', skipna=True)

meanI3.MLDP[0].max(skipna=True).values
# Out:
# /usr/local/lib/python3.5/dist-packages/xarray/core/nanops.py:162: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /usr/local/lib/python3.5/dist-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# array(381.4881, dtype=float32)

# %%
# %matplotlib notebook

plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)

x_n, y_n = Grid(norI1)

projection = ccrs.PlateCarree(360)
region = [lon1, lon2, lat1, lat2]    #Lon, Lat

# Variables to plot
mapping_var = meanI3.MLDP[0]    # In the colormap
contour_var = stdvI3.MLDP[0]    # Variable to plot in lines

cb_label = 'mean MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(10., 700., 25)
n_lines = 11


## Title for the figure
fig_title = 'Nordic Sea Mixed Layer Depth [m] \n ISAS-0.015'  

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                        figsize=(10,5)) 

Map(ax, region, xtik, ytik)

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='max')

cbar = fig.colorbar(contr1, ax=ax, shrink=0.95, orientation='vertical',
                    label=cb_label) 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k')


#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=8, inline=10)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-mld-ms-I3.png', bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py:6449: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py:6449: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)

# %%
meanI4 = norI4.mean(dim='time', skipna=True)
stdvI4 = norI4.std(dim='time', skipna=True)

meanI4.MLDP[0].max(skipna=True).values
# Out:
# /usr/local/lib/python3.5/dist-packages/xarray/core/nanops.py:162: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /usr/local/lib/python3.5/dist-packages/numpy/lib/nanfunctions.py:1545: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# array(736.131, dtype=float32)

# %%
# %matplotlib notebook

plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)

x_n, y_n = Grid(norI1)

projection = ccrs.PlateCarree(360)
region = [lon1, lon2, lat1, lat2]    #Lon, Lat

# Variables to plot
mapping_var = meanI4.MLDP[0]    # In the colormap
contour_var = stdvI4.MLDP[0]    # Variable to plot in lines

cb_label = 'mean MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(10., 700., 25)
n_lines = 11


## Title for the figure
fig_title = 'Nordic Sea Mixed Layer Depth [m] \n ISAS-0.046'  

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                        figsize=(10,5)) 

Map(ax, region, xtik, ytik)

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='max')

cbar = fig.colorbar(contr1, ax=ax, shrink=0.95, orientation='vertical',
                    label=cb_label) 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k')


#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=8, inline=10)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-mld-ms-I4.png', bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py:6449: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /usr/local/lib/python3.5/dist-packages/numpy/ma/core.py:6449: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# /usr/lib/python3/dist-packages/matplotlib/contour.py:370: RuntimeWarning: invalid value encountered in true_divide
#   dist = np.add.reduce(([(abs(s)[i] / L[i]) for i in range(xsize)]), -1)

# %% [markdown]
# ## Mean + std :: geopotential heigth

# %%
mean15 = nor15.mean(dim='time', skipna=True)
stdv15 = nor15.std(dim='time', skipna=True)


mini = stdv15.zo[0].where(nor15.mask == 1).min(skipna=True).values
maxi = stdv15.zo[0].where(nor15.mask == 1).max(skipna=True).values


print(mini, maxi)
# Out:
# /usr/local/lib/python3.5/dist-packages/dask/array/reductions.py:384: RuntimeWarning: invalid value encountered in true_divide
#   u = total / n
# /usr/local/lib/python3.5/dist-packages/dask/array/numpy_compat.py:28: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-b1c3724ffbaf> in <module>()
#       3
#       4
# ----> 5 mini = stdv15.zo[0].where(nor15.mask == 1).min(skipna=True).values
#       6 maxi = stdv15.zo[0].where(nor15.mask == 1).max(skipna=True).values
#       7
#
# /usr/local/lib/python3.5/dist-packages/xarray/core/dataarray.py in values(self)
#     403     def values(self):
#     404         """The array's data as a numpy.ndarray"""
# --> 405         return self.variable.values
#     406
#     407     @values.setter
#
# /usr/local/lib/python3.5/dist-packages/xarray/core/variable.py in values(self)
#     381     def values(self):
#     382         """The variable's data as a numpy.ndarray"""
# --> 383         return _as_array_or_item(self._data)
#     384
#     385     @values.setter
#
# /usr/local/lib/python3.5/dist-packages/xarray/core/variable.py in _as_array_or_item(data)
#     205     TODO: remove this (replace with np.asarray) once these issues are fixed
#     206     """
# --> 207     data = np.asarray(data)
#     208     if data.ndim == 0:
#     209         if data.dtype.kind == 'M':
#
# /usr/local/lib/python3.5/dist-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# /usr/local/lib/python3.5/dist-packages/dask/array/core.py in __array__(self, dtype, **kwargs)
#    1116
#    1117     def __array__(self, dtype=None, **kwargs):
# -> 1118         x = self.compute()
#    1119         if dtype and x.dtype != dtype:
#    1120             x = x.astype(dtype)
#
# /usr/local/lib/python3.5/dist-packages/dask/base.py in compute(self, **kwargs)
#     153         dask.base.compute
#     154         """
# --> 155         (result,) = compute(self, traverse=False, **kwargs)
#     156         return result
#     157
#
# /usr/local/lib/python3.5/dist-packages/dask/base.py in compute(*args, **kwargs)
#     390     keys = [x.__dask_keys__() for x in collections]
#     391     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 392     results = schedule(dsk, keys, **kwargs)
#     393     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     394
#
# /usr/local/lib/python3.5/dist-packages/dask/threaded.py in get(dsk, result, cache, num_workers, **kwargs)
#      74     results = get_async(pool.apply_async, len(pool._pool), dsk, result,
#      75                         cache=cache, get_id=_thread_get_id,
# ---> 76                         pack_exception=pack_exception, **kwargs)
#      77
#      78     # Cleanup pools associated to dead threads
#
# /usr/local/lib/python3.5/dist-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     490             # Main loop, wait on tasks to finish, insert new ones
#     491             while state['waiting'] or state['ready'] or state['running']:
# --> 492                 key, res_info, failed = queue_get(queue)
#     493                 if failed:
#     494                     exc, tb = loads(res_info)
#
# /usr/local/lib/python3.5/dist-packages/dask/local.py in queue_get(q)
#     139 else:
#     140     def queue_get(q):
# --> 141         return q.get()
#     142
#     143
#
# /usr/lib/python3.5/queue.py in get(self, block, timeout)
#     162             elif timeout is None:
#     163                 while not self._qsize():
# --> 164                     self.not_empty.wait()
#     165             elif timeout < 0:
#     166                 raise ValueError("'timeout' must be a non-negative number")
#
# /usr/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %%
plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)


x_n, y_n = Grid(nor1)

projection = ccrs.PlateCarree(360)
region = [lon1, lon2, lat1, lat2]    #Lon, Lat

# Variables to plot
mapping_var = stdv15.zo[0].where(nor15.mask == 1)    # In the colormap
contour_var = mean15.zo[0].where(nor15.mask == 1)    # Variable to plot in lines

# Parameters for the plot
cb_label = 'SSH std [m]'    # Label for colorbar
cmap = 'PuRd'
levels = np.linspace(0.01, 0.25, 20)
n_lines = 15

fig_title = 'Nordic Sea SSH [m] \n standard deviation in colormap and mean in contours'

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                       figsize=(10,5))    

Map(ax, region, xtik, ytik)

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='neither')

cbar = fig.colorbar(contr1, ax=ax, shrink=0.95, orientation='vertical',
                    label=cb_label, extend='neither') 
cbar.set_ticklabels(['{:.2f}'.format(i) for i in np.linspace(0.01, 0.25, 10)]) # set ticks of your format


contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k')


#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=7, inline=5)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-ssh-ms.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Color map: std MLD and contour std SSH

# %%
# Variables to plot
mapping_var = stdv.mlotst.where(mean.mask == 1)    # In the colormap
contour_var = stdv.zo[0].where(stdv.mask == 1)    # Variable to plot in lines

# Parameters for the plot
cb_label = 'std MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(50., 300., 25)
n_lines = 11

fig_title = 'MLD [m] standar deviation in color map \n SSH [m] standar deviation in contours'

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), figsize=(15,10))    

Map(ax, region, xtik, ytik)
contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='both')

cbar = fig.colorbar(contr1, ax=ax, shrink=0.65, orientation='vertical',
                    label=cb_label, extend='neither') 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k')


#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=8, inline=5)
ax.set_title(fig_title, fontsize=14)

plt.savefig('/home/lgarcia/Documents/Scripts/Images/Noe-mldssh-std-f.png')
plt.show()
