# %%
import xarray as xr
import numpy as np
import datetime
import pandas as pd
#import gsw
from scipy import interpolate

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.path as mpath


import cartopy
import cartopy.feature as cfeat
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import xarray as xr
import numpy as np

from matplotlib import colors
from matplotlib import ticker
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
from mpl_toolkits.axes_grid1 import make_axes_locatable

import matplotlib.animation as animation
from IPython.display import HTML

import warnings; warnings.simplefilter('ignore')

# %%
# Coordinates for large regions. Position in
# (lon, lat): (rigth,  letf), (south, north),
# and title for an eventual ploting title.
reg_ext = {
    'lab': {
        'lon' : (-60, -30),
        'lat' : (50, 65),
        'name' : 'Labrador and Irminger Seas'
    },
    'gul': {
        'lon' : (-75, -45),
        'lat' : (30, 45),
        'name' : 'Gulf Stream'
    },
    'noe': {
        'lon' : (-30, -5),
        'lat' : (45, 60),
        'name' : 'North East Sea'
    },
    'nor':{
        'lon' : (-30, 20.),
        'lat' : (60, 85),
        'name' : 'North Atlantic Ocean'
    },
    'noa':{
        'lon' : (-90, 15.),
        'lat' : (10, 85),
        'name' : 'North Atlantic Ocean'
    }
}

# %%
## Function to crop the dataset
def Crops(coord, d_set):
    """
        Crops is a function that takes a data set and crops it into smaller
        region, using as parameters the values given by the dictionary 
        reg_ext.
        
        Parameters:
        ------------
            
        coord : string
            Key value that identifies the region to obtain
        
        d_set : DataArray
            Dataset to be cropped
        
        Output:
        -------
        new_ds : DataArray
            New data array corresponding to the region stated by 'coord'
    """
    
    lon1, lon2 = reg_ext[coord]['lon']
    lat1, lat2 = reg_ext[coord]['lat']
    name_fig = reg_ext[coord]['name']
    
    new_ds = d_set.sel(longitude=slice(lon1, lon2), latitude=slice(lat1, lat2))
    return(new_ds)


def Grid(data_set):
    x = data_set.longitude
    y = data_set.latitude
    
    x, y = np.meshgrid(x, y)
    return(x, y)


def No_nan(a):
    """
        No_nan is a function that helps to filter an array from nan values.
        
        Parameters:
        ------------
        a : Numpy Array
            Is the array we want to filter
        
        Output:
        -------
        a2 : Numpy Arrray
            Array with no nan values in it
    """
    nan_array = np.isnan(a)
    not_nan_array = ~ nan_array
    a2 = a[not_nan_array]
    
    return(a2)


def Map(ax, region, xtick, ytick):
    """
        Map is a function that helps to plot the map on a certain projection
        of a region. It always uses 50m definition of coastlines.

        Parameters:
        ------------
        ax : axes
            Current axes object in which is drawn the map.

        region : list
            Set of limit coordinates of the region to plot.
            It has the shape [lon1, lon2, lat1, lat2]

        xtick : np.array
            array containing the number and spacement of ticks 
            in x-axis.

        ytick : np.array
            Array containing the number and spacement of ticks 
            in y-axis.
    """
    ax.set_global()
    ax.coastlines('50m')
    #ax.set_xticks(xtick, crs=ccrs.PlateCarree())
    #ax.set_yticks(ytick, crs=ccrs.PlateCarree())
    lon_formatter = LongitudeFormatter(zero_direction_label=True)
    lat_formatter = LatitudeFormatter()

    ax.xaxis.set_major_formatter(lon_formatter)
    ax.yaxis.set_major_formatter(lat_formatter)
    ax.add_feature(cartopy.feature.BORDERS, linestyle=':')
    ax.set_extent(region, crs=ccrs.PlateCarree())     #lat, lon
    ax.gridlines(crs=ccrs.PlateCarree(), linewidth=1, 
                 color='gray', alpha=0.5, linestyle='-.')



## Need to make this a little bit more general, also in the extend. by now extends just to max
def Plot_2D(data_set, reg, *cm_levs, t=None, cmap=None, ext=None, cont_line=False, nlines=None):
    """
        Plot_2D is a function that plots a 2D variable using a
        colormap over a spatial region. It makes use of the external 
        functions 'Grid' and 'Map'. It also makes use of the dictionary 
        'reg_ext', to get the spatial delimitations. This works only
        for DataArray type and to plot MLD. The pre-defined cmap is 
        'magma_r'.
        
        Parameters:
        ------------
        data_set : DataArray
            Current axes object in which is drawn the map. It can
            be a complete DataArray, or just the values for one of
            the variables.
            
        reg : string
            Abreviation name that identifies the region in 
            which the plot is being done. It must be defined
            inside the dictionary 'reg_ext'.
            
        cm_levs : tuple, integers
            It contains the parameters for the color bar. The 
            order is: minimum, maximum, #of levels
        
        t : integer
            Timestep to plot.
        
        cmap : String
            Name of the color map to use. Default is 'magma_r'
        
        ext : string
            Extention of the color bar. Default is 'max'
            
        cont_line : Boolean
            If True we allow to plot a second contour plot of SSH. 
            On top of the MLD heat map.
            If False, this function plots a heat map of the variable 
            set by parameter 'data_set'.
            
        nlines : integers
            Is the number of lines to plot the contour plot. It is 
            optional, and is necessary when cont_line=True.
        
        Output:
        ------------
        ax : axes
    """
    
    # Shaping the plot
    x_n, y_n = Grid(data_set)
    projection = ccrs.PlateCarree(360)
    
    # Getting the delimitations and ticks
    lon1, lon2 = reg_ext[reg]['lon']
    lat1, lat2 = reg_ext[reg]['lat']
    xtick = np.linspace(lon1, lon2, num=9)
    ytick = np.linspace(lat1, lat2, num=4)
    region = [lon1, lon2, lat1, lat2]    #Lon, Lat
    
    # If we want to plot MLD and SSH, or other thing, without SSH countours
    if cont_line:
        if not t:
            variable1 = data_set.mlotst
            variable2 = data_set.zo[0]
        else:
            variable1 = data_set.mlotst[t]
            variable2 = data_set.zo[t,0]
    else:
        if not t:
            variable1 = data_set
        else:
            variable1 = data_set[t]
        
    if not cmap:
        cmap = 'plasma_r'
        
    
    if ext:
        ext = ext
    else:
        ext = 'max'

    # Start of the plot
    fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), figsize=(10,5))    
    
    Map(ax, region, xtick, ytick)
    
    # Here plot the variable using a heat map, defining also color bar
    contr1 = ax.contourf(x_n, y_n, variable1, 
                         levels=np.linspace(cm_levs[0], cm_levs[1], cm_levs[2]),
                         cmap=cmap, extend=ext)
    cbar = fig.colorbar(contr1, ax=ax, shrink=0.855, orientation='vertical',
                        label='MLD [m]', extend=ext)  
    # Here adding an extra layer of SSH at surface using countour lines
    if cont_line:
        contr2 = ax.contour(x_n, y_n, variable2, nlines, linewidths=0.5, colors='k')
    
    # Saving the figure
    ##if save:
    ##    fig.savefig(os.path.abspath(os.path.sep.join([".","dummy_images","Noe_%0.4d.png" % it])))

    return(ax)
    
    
def Masking(data_set, cond):
    """
        Maskin is a function that makes a mask of an array depending on the 
        entering condition. The condition is evaluated over finite numbers.
        At the final, the mask is appended in the original DataArray as a 
        new coordinate.
        
        Parameters:
        ------------
        data_set : DataArray
            Is the array we want to make the mask of.
            
        cond : array
            Codition to meet. 


        Output:
        -------
        data_set : Numpy Arrray
            Array with new coordinates 'mask'
    """
    
    mask = 1 * np.ones((data_set.dims['latitude'], data_set.dims['longitude'])) * np.isfinite(cond)  
    data_set.coords['mask'] = (('latitude', 'longitude'), mask)
    return(data_set)


def Limits(data_set):
    
    mn = data_set.min(skipna=True).values
    mx = data_set.max(skipna=True).values
    return(mn, mx)

# %%
###############################################################################
###########         MAIN PROGRAM
###############################################################################

dir_1 = '../../../New_ARMOR/'
dir_15 = '/net/data0-gw/data0/project/drakkar/USERS/lgarcia/data_ARMOR/'
dir_2= '/net/alpha/exports/sciences/data/LPO_ISAS/ANA_ISAS15/fld2D/'

dir_o = '/home/lgarcia/Documents/Scripts/Images_01/'


fl_n1 = 'NARMOR_*.nc'
fl_n15 = 'ARMOR_*.nc'

c_armor1 = xr.open_mfdataset(dir_1 + fl_n1, concat_dim='time')
c_armor15 = xr.open_mfdataset(dir_15 + fl_n15)


fl_n2 = 'ISAS15_DM_2002_2015_MLDS_0.03.nc'
fl_n3 = 'ISAS15_DM_2002_2015_MLDS_0.015.nc'
fl_n4 = 'ISAS15_DM_2002_2015_MLDS_0.046.nc'

c_isas1 = xr.open_dataset(dir_2 + fl_n2, autoclose=True)
c_isas2 = xr.open_dataset(dir_2 + fl_n3, autoclose=True)
c_isas3 = xr.open_dataset(dir_2 + fl_n4, autoclose=True)

# %%
d1 = datetime.datetime(2005,1,1)
d2 = datetime.datetime(2018,12,20)

weeks = pd.date_range(start=d1, end=d2, freq='7D')
c_armor1.coords['time'] = (('time'), weeks)

# %%
reg = 'nor'
## File format :: t, lat, lon
nor1 = Crops(reg, c_armor1)
nor15 = Crops(reg, c_armor15)

nor15 = Masking(nor15, nor15.to[0,18])
nor_small = nor1.sel(time=slice('2006-01-01', '2015-12-31'))


norI1 = Crops(reg, c_isas1)  ##030
norI2 = Crops(reg, c_isas2)  ##015
norI3 = Crops(reg, c_isas3)  ##046

# %%
##del c_armor1, c_armor15, c_isas1, c_isas2, c_isas3

# %% [markdown]
# ## Mean for complete ARMOR:: 2005-2018

# %%
mean1 = nor1.mean(dim='time', skipna=True)
stdv1 = nor1.std(dim='time', skipna=True)

# All dataset
min_mldm, max_mldm = Limits(mean1.mlotst.where(nor15.mask==1))    # Min, max values mean MLD
min_mlds, max_mlds = Limits(stdv1.mlotst.where(nor15.mask==1))    # Min, max values std MLD

print('mean \t\t std')
print(min_mldm, max_mldm, min_mlds, max_mlds)
# Out:
# mean 		 std
# 13.034293552812072 201.48076923076923 3.4312192465237548 393.7494449943115

# %%
reg = 'nor'

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
region = [lon1, lon2, lat1, lat2]    #Lon, Lat

xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)

x_n, y_n = Grid(nor1)

# %%
projection = ccrs.AlbersEqualArea(central_longitude=-5,
                            central_latitude=75,
                            standard_parallels=(lat1, lat2))
data_crs = ccrs.PlateCarree()

# %%
## Mean + std :: MLD

# %matplotlib notebook

plt.close()

# Variables to plot
mapping_var = mean1.mlotst.where(nor15.mask==1)   # In the colormap
contour_var = stdv1.mlotst.where(nor15.mask==1)   # Variable to plot in lines

cb_label = 'mean MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(13., 200., 25)
n_lines = 7


## Title for the figure
fig_title = 'Nordic Sea \nMixed Layer Depth [m]'  



fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                     figsize=(5,5)) 

ax = plt.axes(projection=projection)    


Map(ax, region, xtik, ytik)

contr = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='neither', transform=data_crs)
cbar = fig.colorbar(contr, ax=ax, shrink=0.85, orientation='vertical',
                    label=cb_label) 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k', transform=data_crs)


vertices = [(lon, lat1) for lon in range(int(lon1), int(lon2+1), 1)]+ \
           [(lon, lat2) for lon in range(int(lon2), int(lon1+1), -1)]

boundary = mpath.Path(vertices)
ax.set_boundary(boundary, transform=data_crs)

ax.clabel(contr2, fontsize=8, inline=10)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-mld-ms.png', bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Mean for datasets:: 2006-2016

# %% [markdown]
# ### ARMOR 3D

# %%
mean_a = nor_small.mean(dim='time', skipna=True)
stdv_a = nor_small.std(dim='time', skipna=True)

# All dataset
min_mldm, max_mldm = Limits(mean_a.mlotst)    # Min, max values mean MLD
min_mlds, max_mlds = Limits(stdv_a.mlotst)    # Min, max values std MLD

print('mean \t\t std')
print(min_mldm, max_mldm, min_mlds, max_mlds)
# Out:
# mean 		 std
# 10.0 216.9021113243762 0.0 449.3805193033485

# %%
reg = 'nor'

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
region = [lon1, lon2, lat1, lat2]    #Lon, Lat

xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)

x_n, y_n = Grid(nor_small)

# %%
projection = projection = ccrs.AlbersEqualArea(central_longitude=-5,
                            central_latitude=75,
                            standard_parallels=(lat1, lat2))
data_crs = ccrs.PlateCarree()

# %%
## Mean + std :: MLD

# %matplotlib notebook

plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)

x_n, y_n = Grid(nor1)

region = [lon1, lon2, lat1, lat2]    #Lon, Lat

# Variables to plot
mapping_var = mean_a.mlotst   # In the colormap
contour_var = stdv_a.mlotst   # Variable to plot in lines

cb_label = 'mean MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(10., 750., 25)#np.linspace(13., 175., 25)
n_lines = 7


## Title for the figure
fig_title = 'Mixed Layer Depth [m] \nARMOR 3D'  

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                     figsize=(5,5)) 

ax = plt.axes(projection=projection)    


Map(ax, region, xtik, ytik)

contr = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='neither', transform=data_crs)
cbar = fig.colorbar(contr, ax=ax, shrink=0.85, orientation='vertical',
                    label=cb_label) 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k', transform=data_crs)


vertices = [(lon, lat1) for lon in range(int(lon1), int(lon2+1), 1)]+ \
           [(lon, lat2) for lon in range(int(lon2), int(lon1+1), -1)]

boundary = mpath.Path(vertices)
ax.set_boundary(boundary, transform=data_crs)

ax.clabel(contr2, fontsize=8, inline=10)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-mld-ms-A.png', bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### ISAS-030

# %%
meanI1 = norI1.mean(dim='time', skipna=True)
stdvI1 = norI1.std(dim='time', skipna=True)

meanI1.MLDP[0].max(skipna=True).values
# Out:
# array(518.9583, dtype=float32)

# %%
# %matplotlib notebook

plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)

x_n, y_n = Grid(norI1)


# Variables to plot
mapping_var = meanI1.MLDP[0]    # In the colormap
contour_var = stdvI1.MLDP[0]    # Variable to plot in lines

cb_label = 'mean MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(10., 750., 25)
n_lines = 7


## Title for the figure
fig_title = 'Nordic Sea Mixed Layer Depth [m] \n ISAS-0.030'  

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                        figsize=(5,5)) 

ax = plt.axes(projection=projection)    
Map(ax, region, xtik, ytik)

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='neither',
                    transform=data_crs)

cbar = fig.colorbar(contr1, ax=ax, shrink=0.95, orientation='vertical',
                    label=cb_label) 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k',
                   transform=data_crs)

vertices = [(lon, lat1) for lon in range(int(lon1), int(lon2+1), 1)]+ \
           [(lon, lat2) for lon in range(int(lon2), int(lon1+1), -1)]

boundary = mpath.Path(vertices)
ax.set_boundary(boundary, transform=data_crs)

#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=8, inline=10)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-mld-ms-I1.png', bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### ISAS-015

# %%
meanI2 = norI2.mean(dim='time', skipna=True)
stdvI2 = norI2.std(dim='time', skipna=True)

meanI2.MLDP[0].max(skipna=True).values
# Out:
# array(381.4881, dtype=float32)

# %%
# %matplotlib notebook

plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)

x_n, y_n = Grid(norI1)

region = [lon1, lon2, lat1, lat2]    #Lon, Lat

# Variables to plot
mapping_var = meanI2.MLDP[0]    # In the colormap
contour_var = stdvI2.MLDP[0]    # Variable to plot in lines

cb_label = 'mean MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(5., 750., 25)
n_lines = 5


## Title for the figure
fig_title = 'Nordic Sea Mixed Layer Depth [m] \n ISAS-0.015'  

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                        figsize=(5,5)) 

ax = plt.axes(projection=projection)    
Map(ax, region, xtik, ytik)

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='neither',
                    transform=data_crs)

cbar = fig.colorbar(contr1, ax=ax, shrink=0.95, orientation='vertical',
                    label=cb_label) 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k',
                   transform=data_crs)

vertices = [(lon, lat1) for lon in range(int(lon1), int(lon2+1), 1)]+ \
           [(lon, lat2) for lon in range(int(lon2), int(lon1+1), -1)]

boundary = mpath.Path(vertices)
ax.set_boundary(boundary, transform=data_crs)

#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=8, inline=10)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-mld-ms-I2.png', bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### ISAS-046

# %%
meanI3 = norI3.mean(dim='time', skipna=True)
stdvI3 = norI3.std(dim='time', skipna=True)

meanI3.MLDP[0].max(skipna=True).values
# Out:
# array(736.131, dtype=float32)

# %%
# %matplotlib notebook

plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
region = [lon1, lon2, lat1, lat2]    #Lon, Lat

xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)
x_n, y_n = Grid(norI1)



# Variables to plot
mapping_var = meanI3.MLDP[0]    # In the colormap
contour_var = stdvI3.MLDP[0]    # Variable to plot in lines

cb_label = 'mean MLD [m]'    # Label for colorbar
cmap = 'YlGnBu'
levels = np.linspace(10., 750., 25)
n_lines = 5

## Title for the figure
fig_title = 'Nordic Sea Mixed Layer Depth [m] \n ISAS-0.046'  

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                        figsize=(5,5)) 

ax = plt.axes(projection=projection)    
Map(ax, region, xtik, ytik)

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='neither',
                    transform=data_crs)

cbar = fig.colorbar(contr1, ax=ax, shrink=0.95, orientation='vertical',
                    label=cb_label) 

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k',
                   transform=data_crs)

vertices = [(lon, lat1) for lon in range(int(lon1), int(lon2+1), 1)]+ \
           [(lon, lat2) for lon in range(int(lon2), int(lon1+1), -1)]

boundary = mpath.Path(vertices)
ax.set_boundary(boundary, transform=data_crs)

#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=8, inline=10)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-mld-ms-I3.png', bbox_inches='tight')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Mean + std :: geopotential heigth

# %%
mean15 = nor15.mean(dim='time', skipna=True)
stdv15 = nor15.std(dim='time', skipna=True)


mini = stdv15.zo[0].where(nor15.mask == 1).min(skipna=True).values
maxi = stdv15.zo[0].where(nor15.mask == 1).max(skipna=True).values


print(mini, maxi)

# %%
plt.close()

lon1, lon2 = reg_ext[reg]['lon']
lat1, lat2 = reg_ext[reg]['lat']
x_n, y_n = Grid(nor1)

xtik = np.linspace(lon1, lon2, num=6)
ytik = np.linspace(lat1, lat2, num=4)
region = [lon1, lon2, lat1, lat2]    #Lon, Lat

# Variables to plot
mapping_var = stdv15.zo[0].where(nor15.mask == 1)    # In the colormap
contour_var = mean15.zo[0].where(nor15.mask == 1)    # Variable to plot in lines

# Parameters for the plot
cb_label = 'SSH std [m]'    # Label for colorbar
cmap = 'PuRd'
levels = np.linspace(0.02, 0.15, 20)
n_lines = 15

fig_title = 'Nordic Sea SSH [m]'

fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(projection=projection), 
                       figsize=(5,5))    

ax = plt.axes(projection=projection)    
Map(ax, region, xtik, ytik)

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='neither')

contr1 = ax.contourf(x_n, y_n, mapping_var, levels=levels, cmap=cmap, extend='neither',
                    transform=data_crs)

cbar = fig.colorbar(contr1, ax=ax, shrink=0.95, orientation='vertical',
                    label=cb_label) 

cbar.set_ticklabels(['{:.2f}'.format(i) for i in np.linspace(0.02, 0.15, 7)]) # set ticks of your format

contr2 = ax.contour(x_n, y_n, contour_var, n_lines, linewidths=1, colors='k',
                   transform=data_crs)



vertices = [(lon, lat1) for lon in range(int(lon1), int(lon2+1), 1)]+ \
           [(lon, lat2) for lon in range(int(lon2), int(lon1+1), -1)]

boundary = mpath.Path(vertices)
ax.set_boundary(boundary, transform=data_crs)


#cbar.set_clim(vmin=0., vmax=300.)
ax.clabel(contr2, fontsize=7, inline=5)
ax.set_title(fig_title, fontsize=14)

plt.savefig(dir_o + 'Nor-ssh-ms.png', bbox_inches='tight')
plt.show()

# %%
cartopy.__version__
# Out:
# '0.16.0'

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs


plain_crs = ccrs.PlateCarree()
mercator_crs = ccrs.Mercator()
rotated_crs = ccrs.RotatedPole(pole_longitude=120.0, pole_latitude=45.0)
igh_crs = ccrs.InterruptedGoodeHomolosine()
polar_crs = ccrs.SouthPolarStereo()
uk_extent = [-10, 3, 49, 59]
north_atlantic_extent = [-90, 0, -10, 70]
polar_extent = [-180, 180, -90, -60]

to_test = [(plain_crs, uk_extent),
           (mercator_crs, uk_extent),
           (rotated_crs, uk_extent),
           (rotated_crs, north_atlantic_extent),
           (igh_crs, north_atlantic_extent),
           (polar_crs, polar_extent)]

for projection, extent in to_test:

    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(1, 1, 1, projection=projection)
    ax.set_extent(extent, crs=plain_crs)
    ax.coastlines(resolution='50m', color='k')
    ax.gridlines(color='lightgrey', linestyle='-', draw_labels=True)

plt.show()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-a98763482089> in <module>()
#      25     ax.set_extent(extent, crs=plain_crs)
#      26     ax.coastlines(resolution='50m', color='k')
# ---> 27     ax.gridlines(color='lightgrey', linestyle='-', draw_labels=True)
#      28
#      29 plt.show()
#
# /usr/local/lib/python3.5/dist-packages/cartopy/mpl/geoaxes.py in gridlines(self, crs, draw_labels, xlocs, ylocs, **kwargs)
#    1213         gl = Gridliner(
#    1214             self, crs=crs, draw_labels=draw_labels, xlocator=xlocs,
# -> 1215             ylocator=ylocs, collection_kwargs=kwargs)
#    1216         self._gridliners.append(gl)
#    1217         return gl
#
# /usr/local/lib/python3.5/dist-packages/cartopy/mpl/gridliner.py in __init__(self, axes, crs, draw_labels, xlocator, ylocator, collection_kwargs)
#     183         # public attributes are changed after instantiation.
#     184         if draw_labels:
# --> 185             self._assert_can_draw_ticks()
#     186
#     187         #: The number of interpolation points which are used to draw the
#
# /usr/local/lib/python3.5/dist-packages/cartopy/mpl/gridliner.py in _assert_can_draw_ticks(self)
#     397                             '{prj.__class__.__name__} plot.  Only PlateCarree'
#     398                             ' and Mercator plots are currently '
# --> 399                             'supported.'.format(prj=self.axes.projection))
#     400         return True
#     401
#
# TypeError: Cannot label gridlines on a RotatedPole plot.  Only PlateCarree and Mercator plots are currently supported.
